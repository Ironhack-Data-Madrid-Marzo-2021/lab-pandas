# %% [markdown]
# # Introduction to Pandas Lab
#
# Complete the following set of exercises to solidify your knowledge of Pandas fundamentals.

# %% [markdown]
# ### 1. Import Numpy and Pandas and alias them to `np` and `pd` respectively.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Create a Pandas Series containing the elements of the list below.

# %%
lst = [5.7, 75.2, 74.4, 84.0, 66.5, 66.3, 55.8, 75.7, 29.1, 43.7]

# %%
serie = pd.Series(lst)
print(serie)
# Out:
# 0     5.7
# 1    75.2
# 2    74.4
# 3    84.0
# 4    66.5
# 5    66.3
# 6    55.8
# 7    75.7
# 8    29.1
# 9    43.7
# dtype: float64

# %% [markdown]
# ### 3. Use indexing to return the third value in the Series above.
#
# *Hint: Remember that indexing begins at 0.*

# %%
serie.iloc[[2]]
# Out:
# 2    74.4
# dtype: float64

# %% [markdown]
# ### 4. Create a Pandas DataFrame from the list of lists below. Each sublist should be represented as a row.

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
df4 = pd.DataFrame(b) 
print(df4)
# Out:
#       0     1     2     3     4
# 0  53.1  95.0  67.5  35.0  78.4
# 1  61.3  40.8  30.8  37.8  87.6
# 2  20.6  73.2  44.2  14.6  91.8
# 3  57.4   0.1  96.1   4.2  69.5
# 4  83.6  20.5  85.4  22.8  35.9
# 5  49.0  69.0   0.1  31.8  89.1
# 6  23.3  40.7  95.0  83.8  26.9
# 7  27.6  26.4  53.8  88.8  68.5
# 8  96.6  96.4  53.4  72.4  50.1
# 9  73.7  39.0  43.2  81.6  34.7

# %% [markdown]
# ### 5. Rename the data frame columns based on the names in the list below.

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
colnames = ['Score_1', 'Score_2', 'Score_3', 'Score_4', 'Score_5']

# %%
df4 = pd.DataFrame(b, columns=['Score_1', 'Score_2', 'Score_3', 'Score_4', 'Score_5']) 
print(df4)
# Out:
#    Score_1  Score_2  Score_3  Score_4  Score_5
# 0     53.1     95.0     67.5     35.0     78.4
# 1     61.3     40.8     30.8     37.8     87.6
# 2     20.6     73.2     44.2     14.6     91.8
# 3     57.4      0.1     96.1      4.2     69.5
# 4     83.6     20.5     85.4     22.8     35.9
# 5     49.0     69.0      0.1     31.8     89.1
# 6     23.3     40.7     95.0     83.8     26.9
# 7     27.6     26.4     53.8     88.8     68.5
# 8     96.6     96.4     53.4     72.4     50.1
# 9     73.7     39.0     43.2     81.6     34.7

# %% [markdown]
# ### 6. Create a subset of this data frame that contains only the Score 1, 3, and 5 columns.

# %%
subset = df4[['Score_1', 'Score_3', 'Score_5']]
print(subset)
# Out:
#    Score_1  Score_3  Score_5
# 0     53.1     67.5     78.4
# 1     61.3     30.8     87.6
# 2     20.6     44.2     91.8
# 3     57.4     96.1     69.5
# 4     83.6     85.4     35.9
# 5     49.0      0.1     89.1
# 6     23.3     95.0     26.9
# 7     27.6     53.8     68.5
# 8     96.6     53.4     50.1
# 9     73.7     43.2     34.7

# %% [markdown]
# ### 7. From the original data frame, calculate the average Score_3 value.

# %%
average_Score_3 = df4["Score_3"].mean()
print(average_Score_3)
# Out:
# 56.95000000000001

# %% [markdown]
# ### 8. From the original data frame, calculate the maximum Score_4 value.

# %%
max_value_Score_4 = df4["Score_4"].max()
print(max_value_Score_4)
# Out:
# 88.8

# %% [markdown]
# ### 9. From the original data frame, calculate the median Score 2 value.

# %%
median_value_Score_2 = df4['Score_2'].median()
print(median_value_Score_2)
# Out:
# 40.75

# %% [markdown]
# ### 10. Create a Pandas DataFrame from the dictionary of product orders below.

# %%
orders = {'Description': ['LUNCH BAG APPLE DESIGN',
  'SET OF 60 VINTAGE LEAF CAKE CASES',
  'RIBBON REEL STRIPES DESIGN',
  'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
  'PLAYING CARDS JUBILEE UNION JACK',
  'POPCORN HOLDER',
  'BOX OF VINTAGE ALPHABET BLOCKS',
  'PARTY BUNTING',
  'JAZZ HEARTS ADDRESS BOOK',
  'SET OF 4 SANTA PLACE SETTINGS'],
 'Quantity': [1, 24, 1, 2880, 2, 7, 1, 4, 10, 48],
 'UnitPrice': [1.65, 0.55, 1.65, 0.18, 1.25, 0.85, 11.95, 4.95, 0.19, 1.25],
 'Revenue': [1.65, 13.2, 1.65, 518.4, 2.5, 5.95, 11.95, 19.8, 1.9, 60.0]}

# %%
product_orders = pd.DataFrame(orders, columns = ['Description', 'Quantity', 'UnitPrice', 'Revenue']) 
print(product_orders)
# Out:
#                          Description  Quantity  UnitPrice  Revenue
# 0             LUNCH BAG APPLE DESIGN         1       1.65     1.65
# 1  SET OF 60 VINTAGE LEAF CAKE CASES        24       0.55    13.20
# 2         RIBBON REEL STRIPES DESIGN         1       1.65     1.65
# 3  WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880       0.18   518.40
# 4   PLAYING CARDS JUBILEE UNION JACK         2       1.25     2.50
# 5                     POPCORN HOLDER         7       0.85     5.95
# 6     BOX OF VINTAGE ALPHABET BLOCKS         1      11.95    11.95
# 7                      PARTY BUNTING         4       4.95    19.80
# 8           JAZZ HEARTS ADDRESS BOOK        10       0.19     1.90
# 9      SET OF 4 SANTA PLACE SETTINGS        48       1.25    60.00

# %% [markdown]
# ### 11. Calculate the total quantity ordered and revenue generated from these orders.

# %%
total_quantity = product_orders['Quantity'].sum()
print(total_quantity)
# Out:
# 2978

# %%
total_revenue = product_orders['Revenue'].sum()
print(total_revenue)
# Out:
# 637.0

# %%
# add the total of just one column

product_orders.loc['Total'] = pd.Series(product_orders['Quantity'].sum(), index = ['Quantity'])
print (product_orders)
# Out:
#                              Description  Quantity  UnitPrice  Revenue
# 0                 LUNCH BAG APPLE DESIGN       1.0       1.65     1.65
# 1      SET OF 60 VINTAGE LEAF CAKE CASES      24.0       0.55    13.20
# 2             RIBBON REEL STRIPES DESIGN       1.0       1.65     1.65
# 3      WORLD WAR 2 GLIDERS ASSTD DESIGNS    2880.0       0.18   518.40
# 4       PLAYING CARDS JUBILEE UNION JACK       2.0       1.25     2.50
# 5                         POPCORN HOLDER       7.0       0.85     5.95
# 6         BOX OF VINTAGE ALPHABET BLOCKS       1.0      11.95    11.95
# 7                          PARTY BUNTING       4.0       4.95    19.80
# 8               JAZZ HEARTS ADDRESS BOOK      10.0       0.19     1.90
# 9          SET OF 4 SANTA PLACE SETTINGS      48.0       1.25    60.00
# Total                                NaN    2978.0        NaN      NaN

# %%
# find the sum of all values along the index axis. skiping the NaN values in the calculation of the sum.

product_orders.sum(axis = 0, skipna = True)
# Out:
# Quantity     5956.00
# UnitPrice      24.47
# Revenue       637.00
# dtype: float64

# %%
# add the total of of all values along the index axis. skiping the NaN values in the calculation of the sum.

product_orders.loc['Total'] = product_orders.sum(axis = 0, skipna = True)
print (product_orders)
# Out:
#                              Description  Quantity  UnitPrice  Revenue
# 0                 LUNCH BAG APPLE DESIGN       1.0       1.65     1.65
# 1      SET OF 60 VINTAGE LEAF CAKE CASES      24.0       0.55    13.20
# 2             RIBBON REEL STRIPES DESIGN       1.0       1.65     1.65
# 3      WORLD WAR 2 GLIDERS ASSTD DESIGNS    2880.0       0.18   518.40
# 4       PLAYING CARDS JUBILEE UNION JACK       2.0       1.25     2.50
# 5                         POPCORN HOLDER       7.0       0.85     5.95
# 6         BOX OF VINTAGE ALPHABET BLOCKS       1.0      11.95    11.95
# 7                          PARTY BUNTING       4.0       4.95    19.80
# 8               JAZZ HEARTS ADDRESS BOOK      10.0       0.19     1.90
# 9          SET OF 4 SANTA PLACE SETTINGS      48.0       1.25    60.00
# Total                                NaN    5956.0      24.47   637.00

# %% [markdown]
# ### 12. Obtain the prices of the most expensive and least expensive items ordered and print the difference.

# %%
max_value_UnitPrice = product_orders["UnitPrice"].max()
print('max', max_value_UnitPrice)

min_value_UnitPrice = product_orders["UnitPrice"].min()
print('min', min_value_UnitPrice)

distance = max_value_UnitPrice - min_value_UnitPrice
print('Distancia de precios', distance)
# Out:
# max 24.47
# min 0.18
# Distancia de precios 24.29

# %%
product_orders.UnitPrice.max()
# Out:
# 24.469999999999999

# %% [markdown]
# ## Let's load another dataset for more exercisesº

# %%
# Run this code:
admissions = pd.read_csv('../Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %%
admissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 9 columns):
# Serial No.           385 non-null int64
# GRE Score            385 non-null int64
# TOEFL Score          385 non-null int64
# University Rating    385 non-null int64
# SOP                  385 non-null float64
# LOR                  385 non-null float64
# CGPA                 385 non-null float64
# Research             385 non-null int64
# Chance of Admit      385 non-null float64
# dtypes: float64(4), int64(5)
# memory usage: 27.1 KB

# %%
admissions.shape
# Out:
# (385, 9)

# %% [markdown]
# ### 1 - Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
null = admissions.isnull()
print(null.head())
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating    SOP    LOR   CGPA  \
# 0       False      False        False              False  False  False  False
# 1       False      False        False              False  False  False  False
# 2       False      False        False              False  False  False  False
# 3       False      False        False              False  False  False  False
# 4       False      False        False              False  False  False  False
#
#    Research  Chance of Admit  Decision  Decision2
# 0     False            False     False      False
# 1     False            False     False      False
# 2     False            False     False      False
# 3     False            False     False      False
# 4     False            False     False      False

# %%
admissions.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# ###  2 -  Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
admissions = admissions.set_index("Serial No.")
admissions.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.72
# 3                  1             0.80
# 4                  0             0.65
# 5                  1             0.90

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
admissions['concatenated'] = admissions['GRE Score'].astype(str) + admissions['CGPA'].astype(str)
print(admissions)
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
# 6                 321          109                  3  3.0  4.0  8.20
# 7                 308          101                  2  3.0  4.0  7.90
# 8                 302          102                  1  2.0  1.5  8.00
# 9                 323          108                  3  3.5  3.0  8.60
# 10                327          111                  4  4.0  4.5  9.00
# 11                328          112                  4  4.0  4.5  9.10
# 12                307          109                  3  4.0  3.0  8.00
# ...

# %%
admissions.concatenated.value_counts()
# Out:
# 3349.7     1
# 3329.36    1
# 3068.36    1
# 3369.53    1
# 3088.34    1
# 2947.36    1
# 3169.0     1
# 3208.62    1
# 3088.07    1
# 3278.4     1
# 3188.27    1
# 2997.86    1
# 3128.09    1
# 3178.57    1
# 3409.45    1
# 3018.22    1
# 3168.56    1
# 3006.8     1
# 3199.04    1
# 3208.64    1
# 3269.23    1
# 3248.64    1
# 3188.67    1
# 2997.34    1
# 2987.86    1
# 3058.16    1
# 3047.66    1
# 2988.54    1
# 3329.1     1
# 3018.34    1
#           ..
# 3319.44    1
# 3058.48    1
# 3028.33    1
# 3239.1     1
# 3117.46    1
# 3068.45    1
# 3187.92    1
# 3168.2     1
# 3208.74    1
# 3078.27    1
# 3229.36    1
# 3138.65    1
# 3248.77    1
# 3399.7     1
# 3218.8     1
# 3249.08    1
# 3048.2     1
# 3219.06    1
# 3088.0     1
# 3369.76    1
# 3088.45    1
# 3118.2     1
# 3359.56    1
# 3359.68    1
# 3047.84    1
# 2987.6     1
# 3369.19    1
# 3369.8     1
# 3118.43    1
# 3218.68    1
# Name: concatenated, Length: 385, dtype: int64

# %% [markdown]
# ### 3 - In this part of the lab, we would like to test complex conditions on the entire data set at once. Let's start by finding the number of rows where the CGPA is greater than 9 and the student has performed an investigation.

# %%
filtrado1 = admissions.loc[(admissions["CGPA"] > 9) & (admissions["Research"] == 1)]
filtrado1.shape
# Out:
# (101, 8)

# %%
filtrado1.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 5                 330          115                  5  4.5  3.0  9.34
# 11                328          112                  4  4.0  4.5  9.10
# 20                328          116                  5  5.0  5.0  9.50
# 21                334          119                  5  5.0  4.5  9.70
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 5                  1             0.90
# 11                 1             0.78
# 20                 1             0.94
# 21                 1             0.95

# %% [markdown]
# #### 4 - Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
filtrado2 = admissions.loc[(admissions["CGPA"] > 9) & (admissions["SOP"] < 3.5)]
filtrado2
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 29                338          118                  4  3.0  4.5  9.40
# 63                327          114                  3  3.0  3.0  9.02
# 141               326          114                  3  3.0  3.0  9.11
# 218               324          111                  4  3.0  3.0  9.01
# 382               325          107                  3  3.0  3.5  9.11
#
#             Research  Chance of Admit concatenated
# Serial No.
# 29                 1             0.91       3389.4
# 63                 0             0.61      3279.02
# 141                1             0.83      3269.11
# 218                1             0.82      3249.01
# 382                1             0.84      3259.11

# %%
#  Find the mean chance of admit for these applicants.

mean_chance_of_admit = filtrado2['Chance of Admit'].mean()
mean_chance_of_admit
# Out:
# 0.8019999999999999

# %% [markdown]
# Let's create a new column based on the TOEFL Score column, where we put True if the TOEFL value is greater than 100 and False if it is less. We are going to do it with a function and an apply.
# To do this, we first create a function that receives an argument. The function will return True if the parameter entered is greater than 100, otherwise it will return False.

# %%
def true_false(row):
    if row['TOEFL Score'] > 100:
        return True
    else:
        return False

admissions.apply(true_false, axis=1)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23     False
# 24     False
# 25     False
# 26     False
# 27      True
# 28      True
# 29      True
#        ...
# 355     True
# 356     True
# 357     True
# 358     True
# 359     True
# 360     True
# 361    False
# 362    False
# 363    False
# 364    False
# 365     True
# 366     True
# 367     True
# 368    False
# 369     True
# 370     True
# 371     True
# 372     True
# 373    False
# 374     True
# 375     True
# 376     True
# 377     True
# 378     True
# 379     True
# 380     True
# 381     True
# 382     True
# 383     True
# 384     True
# Length: 385, dtype: bool

# %% [markdown]
# Now we create a new column called "Decision" and apply to the TOEFL Score column

# %%
admissions['Decision'] = admissions.apply(true_false, axis=1)
admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# 5             6        321          109                  3  3.0  4.0  8.20
# 6             7        308          101                  2  3.0  4.0  7.90
# 7             8        302          102                  1  2.0  1.5  8.00
# 8             9        323          108                  3  3.5  3.0  8.60
# 9            10        327          111                  4  4.0  4.5  9.00
# 10           11        328          112                  4  4.0  4.5  9.10
# ...

# %% [markdown]
# Create a column called `decision2` in the `admissions` dataframe. Assign 1 to this column if the value of `SOP` is greater than 3 and 0 otherwise.
# HINT (use np.where)

# %%
admissions['Decision2'] = np.where(admissions.SOP > 3, 1, 0)
admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# 5             6        321          109                  3  3.0  4.0  8.20
# 6             7        308          101                  2  3.0  4.0  7.90
# 7             8        302          102                  1  2.0  1.5  8.00
# 8             9        323          108                  3  3.5  3.0  8.60
# 9            10        327          111                  4  4.0  4.5  9.00
# 10           11        328          112                  4  4.0  4.5  9.10
# ...
